# %%
import tensorflow as tf

x_data = [1, 2, 3]
y_data = [1, 2, 3]

W = tf.Variable(tf.random_uniform([1], -1.0, 1.0))
b = tf.Variable(tf.random_uniform([1], -1.0, 1.0))

X = tf.placeholder(tf.float32, name="X")
Y = tf.placeholder(tf.float32, name="Y")
print(X)
print(Y)

hypothesis = W * X + b

cost = tf.reduce_mean(tf.square(hypothesis - Y))

optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.1)
train_op = optimizer.minimize(cost)

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    
    for step in range(100):
        _, cost_val = sess.run([train_op, cost], feed_dict={X: x_data, Y: y_data})

        print(step, cost_val, sess.run(W), sess.run(b))
    
    print("\n=== Test ===")
    print("X: 5, Y:", sess.run(hypothesis, feed_dict={X: 5}))
    print("X: 2.5, Y:", sess.run(hypothesis, feed_dict={X: 2.5}))
# Out:
# Tensor("X_6:0", dtype=float32)
# Tensor("Y_6:0", dtype=float32)
# 0 12.18971 [1.2836778] [-0.2427159]
# 1 0.15903974 [1.1159981] [-0.30764386]
# 2 0.014692936 [1.1307908] [-0.29251432]
# 3 0.012360998 [1.1257252] [-0.2863278]
# 4 0.011754312 [1.1229129] [-0.2793523]
# 5 0.011195754 [1.119935] [-0.272647]
# 6 0.010663944 [1.1170545] [-0.26609161]
# 7 0.010157389 [1.1142403] [-0.25969508]
# 8 0.009674912 [1.1114941] [-0.25345218]
# 9 0.009215336 [1.1088139] [-0.24735937]
# 10 0.008777623 [1.106198] [-0.24141306]
# 11 0.008360669 [1.1036451] [-0.23560962]
# 12 0.007963535 [1.1011535] [-0.22994573]
# 13 0.0075852624 [1.0987219] [-0.224418]
# 14 0.007224946 [1.0963486] [-0.21902314]
# 15 0.006881745 [1.0940325] [-0.21375796]
# 16 0.0065548713 [1.0917721] [-0.20861937]
# 17 0.0062435083 [1.0895659] [-0.20360433]
# 18 0.0059469487 [1.0874127] [-0.19870982]
# 19 0.0056644534 [1.0853114] [-0.19393294]
# 20 0.005395383 [1.0832607] [-0.18927091]
# 21 0.0051391055 [1.081259] [-0.184721]
# 22 0.00489499 [1.0793056] [-0.1802804]
# 23 0.0046624723 [1.0773993] [-0.17594658]
# 24 0.0044410094 [1.0755385] [-0.17171697]
# 25 0.00423005 [1.0737227] [-0.16758898]
# 26 0.0040291166 [1.0719504] [-0.16356027]
# 27 0.0038377314 [1.0702208] [-0.15962838]
# 28 0.0036554362 [1.0685328] [-0.15579101]
# 29 0.0034818016 [1.0668854] [-0.15204592]
# 30 0.0033164115 [1.0652775] [-0.14839086]
# 31 0.0031588862 [1.0637082] [-0.14482367]
# 32 0.0030088362 [1.0621767] [-0.14134221]
# 33 0.0028659161 [1.0606819] [-0.13794446]
# 34 0.0027297845 [1.0592232] [-0.13462836]
# 35 0.0026001146 [1.0577996] [-0.13139196]
# 36 0.0024766054 [1.0564101] [-0.12823339]
# 37 0.0023589642 [1.0550541] [-0.12515074]
# 38 0.0022469114 [1.0537306] [-0.12214222]
# 39 0.0021401832 [1.052439] [-0.11920602]
# 40 0.002038526 [1.0511783] [-0.11634041]
# 41 0.0019416896 [1.0499481] [-0.11354365]
# 42 0.0018494548 [1.0487474] [-0.11081415]
# 43 0.0017616096 [1.0475755] [-0.10815028]
# 44 0.0016779345 [1.0464318] [-0.10555042]
# 45 0.0015982268 [1.0453156] [-0.10301304]
# 46 0.00152231 [1.0442263] [-0.10053667]
# 47 0.0014500077 [1.0431631] [-0.09811986]
# 48 0.0013811229 [1.0421255] [-0.09576111]
# 49 0.0013155217 [1.0411128] [-0.09345908]
# 50 0.0012530291 [1.0401245] [-0.09121236]
# 51 0.0011935179 [1.0391599] [-0.08901972]
# 52 0.0011368216 [1.0382185] [-0.08687973]
# 53 0.0010828198 [1.0372998] [-0.08479118]
# 54 0.0010313868 [1.0364031] [-0.08275285]
# 55 0.0009823879 [1.0355281] [-0.0807635]
# 56 0.0009357256 [1.0346739] [-0.07882201]
# 57 0.0008912825 [1.0338404] [-0.07692719]
# 58 0.00084894424 [1.0330269] [-0.07507791]
# 59 0.00080861663 [1.032233] [-0.0732731]
# 60 0.00077020825 [1.0314581] [-0.07151168]
# 61 0.0007336228 [1.0307019] [-0.0697926]
# 62 0.0006987785 [1.0299639] [-0.06811483]
# 63 0.0006655832 [1.0292436] [-0.0664774]
# 64 0.0006339723 [1.0285405] [-0.06487937]
# 65 0.00060385227 [1.0278544] [-0.06331968]
# 66 0.00057517085 [1.0271848] [-0.06179752]
# 67 0.0005478464 [1.0265313] [-0.06031194]
# 68 0.00052182603 [1.0258936] [-0.0588621]
# 69 0.00049703656 [1.0252712] [-0.05744709]
# 70 0.00047342866 [1.0246636] [-0.05606614]
# 71 0.00045094496 [1.0240706] [-0.05471835]
# 72 0.00042952187 [1.0234921] [-0.05340292]
# 73 0.00040911886 [1.0229273] [-0.05211918]
# 74 0.0003896849 [1.0223762] [-0.05086625]
# 75 0.00037117524 [1.0218382] [-0.04964348]
# 76 0.0003535433 [1.0213133] [-0.04845005]
# 77 0.00033675207 [1.0208008] [-0.04728538]
# 78 0.00032075518 [1.0203009] [-0.04614864]
# 79 0.00030551967 [1.0198128] [-0.04503926]
# 80 0.00029100638 [1.0193366] [-0.04395654]
# 81 0.00027718165 [1.0188718] [-0.04289987]
# 82 0.0002640167 [1.0184181] [-0.04186861]
# 83 0.0002514754 [1.0179753] [-0.04086211]
# 84 0.0002395304 [1.0175432] [-0.03987983]
# 85 0.00022815156 [1.0171214] [-0.03892114]
# 86 0.00021731602 [1.0167098] [-0.0379855]
# 87 0.00020699175 [1.0163082] [-0.03707232]
# 88 0.00019715804 [1.0159162] [-0.03618111]
# 89 0.000187793 [1.0155336] [-0.03531137]
# 90 0.00017887443 [1.0151601] [-0.03446253]
# 91 0.00017037836 [1.0147957] [-0.03363406]
# 92 0.00016228484 [1.0144401] [-0.03282551]
# 93 0.00015457673 [1.0140929] [-0.03203644]
# 94 0.00014723312 [1.0137541] [-0.03126632]
# 95 0.00014024127 [1.0134234] [-0.03051471]
# 96 0.00013357885 [1.0131007] [-0.02978114]
# 97 0.00012723473 [1.0127858] [-0.02906523]
# 98 0.00012119004 [1.0124785] [-0.02836649]
# 99 0.000115433504 [1.0121784] [-0.02768459]
#
# === Test ===
# X: 5, Y: [5.0332074]
# X: 2.5, Y: [2.5027614]
